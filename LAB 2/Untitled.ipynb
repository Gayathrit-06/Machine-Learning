# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0,10,20)
y = x**2
plt.plot(x,y,'g')
plt.show()

# %%
x=np.linspace(-np.pi,np.pi,100)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel("Angle")
plt.ylabel("Sine")
plt.title("Sine Function")
plt.show()

# %%
students=["A","B","C","D"]
marks=[80,90,75,95]
plt.bar(students,marks)
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,20,25,30,40]
plt.scatter(x,y)
plt.show()

# %%
marks=[45,50,60,65,70,75,80,90]

plt.hist(marks)

plt.show()

# %%
marks=[40,30,20,10]
subjects=["Python","Java","C","SQL"]
plt.pie(marks,labels=subjects)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sns.load_dataset("tips")
sns.histplot(df["total_bill"])
plt.show()

# %%
data = np.random.rand(5,5)
sns.heatmap(data)
plt.show()

# %%
df = sns.load_dataset("iris")
sns.pairplot(df)

# %%
df = sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.DataFrame({
    "sepal_width":[3.5,3.0,3.2,3.1,3.6,2.9,3.4,3.3]
})

sns.histplot(df1["sepal_width"])
plt.title("Distribution plot for sepal_width")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.DataFrame({
    "sepal_width":[3.5,3.0,3.2,3.1,3.6,2.9,3.4,3.3]
})

sns.kdeplot(df1["sepal_width"])
plt.title("Distribution plot for sepal_width")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "petal_length":[1.4,1.3,1.5,1.7,1.6],
    "petal_width":[0.2,0.3,0.2,0.4,0.3]
})

sns.jointplot(x="petal_length", y="petal_width", data=df)

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

uniform_dt = np.random.rand(10,20)

sns.heatmap(uniform_dt)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "A":[1,2,3,4],
    "B":[4,5,6,7],
    "C":[7,8,9,10]
})

sns.pairplot(df)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Department":["IT","IT","CSE","ECE","CSE"],
    "Marks":[80,85,90,75,88]
})

sns.stripplot(x="Department", y="Marks", data=df)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Marks":[40,45,50,55,60,70,90]
})

sns.boxplot(y=df["Marks"])

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Marks":[40,45,50,55,60,70,90]
})

sns.violinplot(y=df["Marks"])

plt.show()

# %%
import pandas as pd
import numpy as np

data = np.array([1,2,3,4,5])

s = pd.Series(data)

print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
import pandas as pd

data = [[100,37],[101,40],[102,42],[103,57],[104,60]]

df = pd.DataFrame(data, columns=["RegNo","Marks"])

print(df)
# Out:
#    RegNo  Marks
# 0    100     37
# 1    101     40
# 2    102     42
# 3    103     57
# 4    104     60

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42],
    "Marks2":[40,42,43]
})

df["Total"] = df["Marks1"] + df["Marks2"]

print(df)
# Out:
#    Marks1  Marks2  Total
# 0      37      40     77
# 1      40      42     82
# 2      42      43     85

# %%
print(df.sum())
print(df.mean())
print(df.max())
print(df.min())
print(df.describe())
# Out:
# Marks1    119
# Marks2    125
# Total     244
# dtype: int64
# Marks1    39.666667
# Marks2    41.666667
# Total     81.333333
# dtype: float64
# Marks1    42
# Marks2    43
# Total     85
# dtype: int64
# Marks1    37
# Marks2    40
# Total     77
# dtype: int64
#           Marks1     Marks2      Total
# count   3.000000   3.000000   3.000000
# mean   39.666667  41.666667  81.333333
# std     2.516611   1.527525   4.041452
# min    37.000000  40.000000  77.000000
# 25%    38.500000  41.000000  79.500000
# 50%    40.000000  42.000000  82.000000
# 75%    41.000000  42.500000  83.500000
# max    42.000000  43.000000  85.000000

# %%
from scipy import linalg
import numpy as np

a = np.array([[1,2],[3,4]])

print(linalg.det(a))
# Out:
# -2.0

# %%
from scipy import linalg
import numpy as np

a = np.array([[1,2],[3,4]])

print(linalg.inv(a))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
from scipy.stats import chisquare

x = chisquare([40,10,20,30], f_exp=[30,20,30,20])

print(x)
# Out:
# Power_divergenceResult(statistic=16.666666666666668, pvalue=0.0008275246236931499)

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print(iris.data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.4,random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.4,random_state=1)
#
# NameError: name 'X' is not defined

# %%
from sklearn import svm

X = [[0,1],[1,2]]
Y = [0,1]

clf = svm.SVC()

clf.fit(X,Y)

print(clf.predict([[2,2]]))
# Out:
# [1]

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#       4 model = Sequential()
#
# ModuleNotFoundError: No module named 'keras'

# %%
model.fit(X,Y,epochs=150,batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.fit(X,Y,epochs=150,batch_size=10)
#
# NameError: name 'model' is not defined
