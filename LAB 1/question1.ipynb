# %%
import os
print(os.getcwd())
# Out:
# C:\Users\gayat\OneDrive\Desktop\ML\Lab 1

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'sample.csv', 'Untitled.ipynb']

# %%
import pandas as pd
df = pd.read_csv("sample.csv")
print(df)
# Out:
#    id        first       last  gender  Marks  selected
# 0   1        Leone    Debrick  Female     50      True
# 1   2       Romola  Phinnessy  Female     60     False
# 2   3         Geri      Prium    Male     65     False
# 3   4        Sandy   Doveston  Female     95     False
# 4   5      Jacenta     Jansik  Female     31      True
# 5   6  Diane-marie   Medhurst  Female     45      True
# 6   7       Austen       Pool    Male     45      True
# 7   8        Vanya    Teffrey    Male     70     False
# 8   9     Giordano      Elloy    Male     36     False
# 9  10       Rozele    Fawcett  Female     50     False

# %%
df.tail() # it will show last 5 rows
# Out:
#    id        first      last  gender  Marks  selected
# 5   6  Diane-marie  Medhurst  Female     45      True
# 6   7       Austen      Pool    Male     45      True
# 7   8        Vanya   Teffrey    Male     70     False
# 8   9     Giordano     Elloy    Male     36     False
# 9  10       Rozele   Fawcett  Female     50     False

# %%
col_list = ["id","first","gender","Marks","selected"]
df = pd.read_csv("sample.csv", usecols=col_list)
print(df)
# Out:
#    id        first  gender  Marks  selected
# 0   1        Leone  Female     50      True
# 1   2       Romola  Female     60     False
# 2   3         Geri    Male     65     False
# 3   4        Sandy  Female     95     False
# 4   5      Jacenta  Female     31      True
# 5   6  Diane-marie  Female     45      True
# 6   7       Austen    Male     45      True
# 7   8        Vanya    Male     70     False
# 8   9     Giordano    Male     36     False
# 9  10       Rozele  Female     50     False

# %%
mean1 = df["Marks"].mean()
print("Mean Marks : " + str(mean1))
# Out:
# Mean Marks : 54.7

# %%
sum1 = df["Marks"].sum()
print("Sum of the Marks : " + str(sum1))
# Out:
# Sum of the Marks : 547

# %%
max1 = df["Marks"].max()
print("Maximum of the marks : " + str(max1))
# Out:
# Maximum of the marks : 95

# %%
min1 = df["Marks"].min()
print("Minimum of the marks : " + str(min1))
# Out:
# Minimum of the marks : 31

# %%
count1 = df["Marks"].count()
print("Count of the marks : " + str(count1))
# Out:
# Count of the marks : 10

# %%
median1 = df["Marks"].median()
print("Median of the marks : " + str(median1))
# Out:
# Median of the marks : 50.0

# %%
sd1 = df['Marks'].std()
print("Standard deviation of the marks : " + str(sd1))
# Out:
# Standard deviation of the marks : 18.666964283341724

# %%
var1 = df['Marks'].var() 
print("Variance of the marks : " + str(var1))
# Out:
# Variance of the marks : 348.4555555555555
